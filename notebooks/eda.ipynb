# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/wustl_hdrl_2024.csv')
# Out:
# C:\Users\ABHINAV\AppData\Local\Temp\ipykernel_39448\2994708774.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/raw/wustl_hdrl_2024.csv')

# %%
df.shape
# Out:
# (145123, 77)

# %%
df.sample(5)
# Out:
#           Dir        Flgs         SrcAddr      DstAddr  Sport  Dport  \
# 89191      ->   e          198.51.100.100  192.168.4.2  44004   4022
# 112210     ->   e          198.51.100.100  192.168.4.2  60248   4022
# 38773      ->   e          198.51.100.100  192.168.4.2  55096   4022
# 127481     ->   e          198.51.100.100  192.168.4.2  43288   4022
# 69604      ->   e             192.168.3.2  192.168.2.2  40534   4022
#
#         SrcBytes  DstBytes  SrcLoad  DstLoad  ...  sswap_sin  sswap_sout  \
# 89191     1657.0     272.0  10454.0   1608.0  ...          0           0
# 112210    1647.0     272.0  10388.0   1608.0  ...          0           0
# 38773     1653.0     272.0  10428.0   1608.0  ...          0           0
# 127481    1648.0     272.0  10355.0   1602.0  ...          0           0
# 69604     1686.0     272.0  10591.0   1602.0  ...          0           0
#
#         sdiskusage_total  sdiskusage_used  sdiskusage_free  \
# ...

# %%
df.describe()
# Out:
#           Dport       SrcBytes       DstBytes        SrcLoad        DstLoad  \
# count  145123.0  145123.000000  145123.000000  145123.000000  145123.000000
# mean     4022.0    1719.139054     264.862331   10509.177084    1516.387965
# std         0.0     174.272450      30.809559    3372.555854     355.147176
# min      4022.0    1445.000000       0.000000       0.000000       0.000000
# 25%      4022.0    1648.000000     272.000000   10389.000000    1595.000000
# 50%      4022.0    1662.000000     272.000000   10477.000000    1608.000000
# 75%      4022.0    1686.000000     272.000000   10654.000000    1610.000000
# max      4022.0    3406.000000     544.000000  194634.000000   18397.000000
#
#              SrcGap    DstGap       SIntPkt        DIntPkt     SIntPktAct  \
# count  1.451230e+05  145123.0  145123.00000  145123.000000  145123.000000
# mean   3.359426e+02       0.0     207.52576     412.327589       0.011336
# ...
